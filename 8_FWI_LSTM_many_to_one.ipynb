# %%
import torch
import torchvision

import pandas as pd
import numpy as np

# %% [markdown]
# # Seed

# %%
seed_number = 44

torch.manual_seed(seed_number)
torch.cuda.manual_seed(seed_number)
torch.cuda.manual_seed_all(seed_number) # if use multi-GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed_number)
#random.seed(seed_number)

# %% [markdown]
# # Data Load

# %%
df = pd.read_csv('./data/fwi_peru.csv')

print(df.shape)
df.head()
# Out:
# (7670, 8)
#          date       fwi    fbupinx    drtcode   dufmcode    ffmcode    fdsrte  \
# 0  2003-01-01  3.032478  43.350230  303.92447  28.816147  59.494816  0.821229
# 1  2003-01-02  3.234723  43.817448  306.08072  29.067446  58.859665  0.910691
# 2  2003-01-03  3.840679  44.936455  309.48050  29.878538  64.760050  1.050648
# 3  2003-01-04  4.291818  45.781628  312.24307  30.441364  65.765340  1.283834
# 4  2003-01-05  4.434349  46.758377  315.64978  31.114819  65.916730  1.326426
#
#     infsinx
# 0  1.228552
# 1  1.194067
# 2  1.604336
# 3  1.759281
# 4  1.818198

# %%
df.tail()
# Out:
#             date       fwi    fbupinx    drtcode   dufmcode    ffmcode  \
# 7665  2023-12-27  2.525733  36.758522  257.50085  24.618862  35.218212
# 7666  2023-12-28  1.647023  30.309649  242.49062  19.879116  40.500847
# 7667  2023-12-29  1.403245  26.050838  236.74654  16.661034  49.327080
# 7668  2023-12-30  1.826561  25.967650  236.96635  16.680098  53.704983
# 7669  2023-12-31  1.933431  24.840988  231.64226  15.873484  38.895653
#
#         fdsrte   infsinx
# 7665  0.861941  0.750828
# 7666  0.516756  0.528351
# 7667  0.337519  0.615339
# 7668  0.466286  0.831606
# 7669  0.583733  0.600974

# %%
df.dtypes
# Out:
# date         object
# fwi         float64
# fbupinx     float64
# drtcode     float64
# dufmcode    float64
# ffmcode     float64
# fdsrte      float64
# infsinx     float64
# dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df.dtypes
# Out:
# date        datetime64[ns]
# fwi                float64
# fbupinx            float64
# drtcode            float64
# dufmcode           float64
# ffmcode            float64
# fdsrte             float64
# infsinx            float64
# dtype: object

# %%
df_train = df[df['date'].dt.year < 2019]
df_test  = df[df['date'].dt.year >= 2019]

print(df_train.shape)
print(df_test.shape)
# Out:
# (5844, 8)
# (1826, 8)

# %%
X = df_train[['fwi', 'fbupinx', 'drtcode', 'dufmcode', 'ffmcode', 'fdsrte', 'infsinx']].values
y = df_train['fwi'].values

X_test = df_test[['fwi', 'fbupinx', 'drtcode', 'dufmcode', 'ffmcode', 'fdsrte', 'infsinx']].values
y_test = df_test['fwi'].values

print(X.shape, y.shape)
print(X_test.shape, y_test.shape)
# Out:
# (5844, 7) (5844,)
# (1826, 7) (1826,)

# %% [markdown]
# # Normalization

# %%
X_max = np.max(X, axis=0)
X_min = np.min(X, axis=0)

X      = (X      - X_min) / (X_max - X_min + 1e-10)
X_test = (X_test - X_min) / (X_max - X_min + 1e-10)

# %%
print(np.max(X), np.min(X))
print(np.max(X_test), np.min(X_test))
# Out:
# 0.9999999999997156 0.0
# 1.1532220684416759 0.00043293813048260325

# %% [markdown]
# # Data organize (sequence)

# %%
sequence_length = 4

# %%
def make_sequence(data, sequence_length):
    data_seq = []
    for i in range(len(data)-sequence_length):
        data_seq.append(data[i:i+sequence_length])
            
    data_seq = np.stack(data_seq, axis=0)    
    return data_seq

# %%
X_seq = make_sequence(X[:-1], sequence_length=sequence_length)
X_test = make_sequence(X_test[:-1], sequence_length=sequence_length)

y_seq = y[sequence_length+1:]
y_test = y_test[sequence_length+1:]

print(X_seq.shape)
print(y_seq.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5839, 4, 7)
# (5839,)
# (1821, 4, 7)
# (1821,)

# %% [markdown]
# # Split data

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_seq, y_seq, test_size=0.2, random_state=seed_number)

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
# Out:
# (4671, 4, 7) (4671,)
# (1168, 4, 7) (1168,)

# %% [markdown]
# # Data loader

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

X_train = torch.FloatTensor(X_train).to(device=device)
X_valid = torch.FloatTensor(X_valid).to(device=device)
X_test  = torch.FloatTensor(X_test).to(device=device)

y_train = torch.FloatTensor(y_train).to(device=device)
y_valid = torch.FloatTensor(y_valid).to(device=device)
y_test  = torch.FloatTensor(y_test).to(device=device)
# Out:
# cpu

# %%
train_ds = torch.utils.data.TensorDataset(X_train, y_train)
valid_ds = torch.utils.data.TensorDataset(X_valid, y_valid)

train_loader = torch.utils.data.DataLoader(train_ds, batch_size=128, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_ds, batch_size=128, shuffle=False)

# %% [markdown]
# # Model (many to one)

# %%
class Net(torch.nn.Module):
    def __init__(self, n_input, n_hidden, n_layer):
        super(Net, self).__init__()
        
        self.n_input = n_input
        self.n_hidden = n_hidden
        self.n_layer = n_layer
        
        # https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html
        self.LSTM = torch.nn.LSTM(
            n_input, n_hidden, n_layer, 
            bidirectional=False,
            batch_first=True
        )
        
        self.fully_connected_layer_1 = torch.nn.Linear(n_hidden, 32)
        self.fully_connected_layer_2 = torch.nn.Linear(32, 1)
        
    def forward(self, xb):
        h_init = torch.zeros(self.n_layer, xb.size()[0], self.n_hidden)
        c_init = torch.zeros(self.n_layer, xb.size()[0], self.n_hidden)
        out, _ = self.LSTM(xb, (h_init, c_init))
        
        out = self.fully_connected_layer_1(out[:,-1,:])
        out = torch.nn.ReLU()(out)
        out = self.fully_connected_layer_2(out)
        return out

# %%
model = Net(
    n_input=7,
    n_hidden=64,
    n_layer=2,
).to(device)
print(model)
# Out:
# Net(
#   (LSTM): LSTM(7, 64, num_layers=2, batch_first=True)
#   (fully_connected_layer_1): Linear(in_features=64, out_features=32, bias=True)
#   (fully_connected_layer_2): Linear(in_features=32, out_features=1, bias=True)
# )

# %% [markdown]
# # Cost function

# %%
criterion = torch.nn.MSELoss()

# %% [markdown]
# # Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # Training

# %%
import time 

is_train = True
epoch, early_stopping = 0, 0
train_loss_history, valid_loss_history = [], []

while is_train:
    start = time.time()
    train_loss, train_count = 0., 0.
    epoch += 1
    early_stopping += 1
    
    for xb, yb in train_loader:
        prediction = model(xb)
        loss = criterion(prediction[:,0], yb)
        train_loss += loss.item()*len(yb)
        train_count += len(yb)
        
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    with torch.no_grad():
        valid_loss = 0
        valid_count = 0.
        
        for xb, yb in valid_loader:
            prediction = model(xb)
            valid_loss += criterion(prediction[:,0], yb)*len(yb)
            valid_count += len(yb)
        
    train_loss /= train_count
    valid_loss /= valid_count    
    
    train_loss_history.append(train_loss)
    valid_loss_history.append(valid_loss)
    
    if min(valid_loss_history) == valid_loss:
        early_stopping = 0
        
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': valid_loss,
        }, './saved_model.pt')
        
    if early_stopping == 30:
        is_train = False
            
    print(f"======== Epoch {epoch} =======")
    print(f"Loss => train:{train_loss:.5f}, valid:{valid_loss:.5f}, Elapsed time => {time.time()-start:.3f} sec")
    print("=======================================\n")
# Out:
# ======== Epoch 1 =======
# Loss => train:30.04323, valid:16.81633, Elapsed time => 0.457 sec
# =======================================
#
# ======== Epoch 2 =======
# Loss => train:8.78355, valid:8.56242, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 3 =======
# Loss => train:6.10186, valid:4.26555, Elapsed time => 0.442 sec
# =======================================
#
# ======== Epoch 4 =======
# Loss => train:2.54397, valid:2.26701, Elapsed time => 0.449 sec
# =======================================
#
# ======== Epoch 5 =======
# Loss => train:1.85931, valid:1.82611, Elapsed time => 0.450 sec
# =======================================
#
# ======== Epoch 6 =======
# Loss => train:1.69943, valid:1.73713, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 7 =======
# Loss => train:1.56347, valid:1.55312, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 8 =======
# Loss => train:1.44473, valid:1.47034, Elapsed time => 0.444 sec
# =======================================
#
# ======== Epoch 9 =======
# Loss => train:1.38841, valid:1.37411, Elapsed time => 0.441 sec
# =======================================
#
# ======== Epoch 10 =======
# Loss => train:1.27566, valid:1.29217, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 11 =======
# Loss => train:1.21817, valid:1.34765, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 12 =======
# Loss => train:1.15432, valid:1.25309, Elapsed time => 0.442 sec
# =======================================
#
# ======== Epoch 13 =======
# Loss => train:1.15855, valid:1.26967, Elapsed time => 0.457 sec
# =======================================
#
# ======== Epoch 14 =======
# Loss => train:1.07314, valid:1.08944, Elapsed time => 0.454 sec
# =======================================
#
# ======== Epoch 15 =======
# Loss => train:1.06780, valid:1.09126, Elapsed time => 0.445 sec
# =======================================
#
# ======== Epoch 16 =======
# Loss => train:1.01691, valid:1.10421, Elapsed time => 0.426 sec
# =======================================
#
# ======== Epoch 17 =======
# Loss => train:1.01081, valid:1.05018, Elapsed time => 0.444 sec
# =======================================
#
# ======== Epoch 18 =======
# Loss => train:1.03091, valid:1.07159, Elapsed time => 0.453 sec
# =======================================
#
# ======== Epoch 19 =======
# Loss => train:0.99936, valid:1.09243, Elapsed time => 0.451 sec
# =======================================
#
# ======== Epoch 20 =======
# Loss => train:0.99392, valid:1.04294, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 21 =======
# Loss => train:0.97871, valid:1.11914, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 22 =======
# Loss => train:1.00210, valid:1.08789, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 23 =======
# Loss => train:1.02596, valid:1.05302, Elapsed time => 0.452 sec
# =======================================
#
# ======== Epoch 24 =======
# Loss => train:0.97737, valid:1.11560, Elapsed time => 0.446 sec
# =======================================
#
# ======== Epoch 25 =======
# Loss => train:1.02254, valid:1.09746, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 26 =======
# Loss => train:0.97395, valid:1.03423, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 27 =======
# Loss => train:0.97010, valid:1.04210, Elapsed time => 0.426 sec
# =======================================
#
# ======== Epoch 28 =======
# Loss => train:0.96107, valid:1.05057, Elapsed time => 0.445 sec
# =======================================
#
# ======== Epoch 29 =======
# Loss => train:0.95283, valid:1.00286, Elapsed time => 0.442 sec
# =======================================
#
# ======== Epoch 30 =======
# Loss => train:0.96825, valid:0.99772, Elapsed time => 0.448 sec
# =======================================
#
# ======== Epoch 31 =======
# Loss => train:0.94656, valid:1.00650, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 32 =======
# Loss => train:0.96279, valid:1.01410, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 33 =======
# Loss => train:0.95020, valid:0.99779, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 34 =======
# Loss => train:0.93285, valid:1.05015, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 35 =======
# Loss => train:0.95824, valid:0.98666, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 36 =======
# Loss => train:0.94356, valid:1.03885, Elapsed time => 0.411 sec
# =======================================
#
# ======== Epoch 37 =======
# Loss => train:0.93213, valid:1.02693, Elapsed time => 0.430 sec
# =======================================
#
# ======== Epoch 38 =======
# Loss => train:0.95393, valid:0.97838, Elapsed time => 0.422 sec
# =======================================
#
# ======== Epoch 39 =======
# Loss => train:0.92517, valid:0.98781, Elapsed time => 0.413 sec
# =======================================
#
# ======== Epoch 40 =======
# Loss => train:0.93194, valid:0.98620, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 41 =======
# Loss => train:0.94369, valid:0.97503, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 42 =======
# Loss => train:0.91869, valid:0.98298, Elapsed time => 0.459 sec
# =======================================
#
# ======== Epoch 43 =======
# Loss => train:0.93231, valid:0.97504, Elapsed time => 0.449 sec
# =======================================
#
# ======== Epoch 44 =======
# Loss => train:0.92567, valid:0.97610, Elapsed time => 0.465 sec
# =======================================
#
# ======== Epoch 45 =======
# Loss => train:0.92763, valid:0.99764, Elapsed time => 0.461 sec
# =======================================
#
# ======== Epoch 46 =======
# Loss => train:0.93132, valid:0.97736, Elapsed time => 0.426 sec
# =======================================
#
# ======== Epoch 47 =======
# Loss => train:0.95810, valid:0.96702, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 48 =======
# Loss => train:0.91472, valid:0.98869, Elapsed time => 0.422 sec
# =======================================
#
# ======== Epoch 49 =======
# Loss => train:0.94216, valid:0.98416, Elapsed time => 0.428 sec
# =======================================
#
# ======== Epoch 50 =======
# Loss => train:0.92599, valid:0.96147, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 51 =======
# Loss => train:0.98066, valid:0.97572, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 52 =======
# Loss => train:0.93592, valid:0.96950, Elapsed time => 0.444 sec
# =======================================
#
# ======== Epoch 53 =======
# Loss => train:0.94882, valid:0.97409, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 54 =======
# Loss => train:0.92895, valid:0.96804, Elapsed time => 0.458 sec
# =======================================
#
# ======== Epoch 55 =======
# Loss => train:0.92816, valid:1.05458, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 56 =======
# Loss => train:0.92165, valid:1.00529, Elapsed time => 0.420 sec
# =======================================
#
# ======== Epoch 57 =======
# Loss => train:0.92292, valid:0.96189, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 58 =======
# Loss => train:0.90315, valid:0.96833, Elapsed time => 0.410 sec
# =======================================
#
# ======== Epoch 59 =======
# Loss => train:0.90340, valid:0.96608, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 60 =======
# Loss => train:0.90721, valid:1.04616, Elapsed time => 0.413 sec
# =======================================
#
# ======== Epoch 61 =======
# Loss => train:0.90974, valid:1.01013, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 62 =======
# Loss => train:0.90716, valid:1.30415, Elapsed time => 0.451 sec
# =======================================
#
# ======== Epoch 63 =======
# Loss => train:0.91662, valid:0.96679, Elapsed time => 0.445 sec
# =======================================
#
# ======== Epoch 64 =======
# Loss => train:0.91722, valid:0.97282, Elapsed time => 0.446 sec
# =======================================
#
# ======== Epoch 65 =======
# Loss => train:0.89414, valid:0.94892, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 66 =======
# Loss => train:0.89717, valid:0.96146, Elapsed time => 0.438 sec
# =======================================
#
# ======== Epoch 67 =======
# Loss => train:0.90950, valid:0.95673, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 68 =======
# Loss => train:0.92143, valid:1.05549, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 69 =======
# Loss => train:0.93541, valid:0.94755, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 70 =======
# Loss => train:0.90027, valid:1.00552, Elapsed time => 0.425 sec
# =======================================
#
# ======== Epoch 71 =======
# Loss => train:0.90165, valid:0.94493, Elapsed time => 0.448 sec
# =======================================
#
# ======== Epoch 72 =======
# Loss => train:0.89320, valid:1.01206, Elapsed time => 0.441 sec
# =======================================
#
# ======== Epoch 73 =======
# Loss => train:0.88399, valid:0.95089, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 74 =======
# Loss => train:0.88821, valid:0.94102, Elapsed time => 0.426 sec
# =======================================
#
# ======== Epoch 75 =======
# Loss => train:0.90656, valid:0.94905, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 76 =======
# Loss => train:0.88993, valid:0.94221, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 77 =======
# Loss => train:0.89256, valid:0.94774, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 78 =======
# Loss => train:0.87975, valid:1.02856, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 79 =======
# Loss => train:0.90138, valid:1.03662, Elapsed time => 0.413 sec
# =======================================
#
# ======== Epoch 80 =======
# Loss => train:0.91298, valid:0.95649, Elapsed time => 0.438 sec
# =======================================
#
# ======== Epoch 81 =======
# Loss => train:0.92823, valid:1.03542, Elapsed time => 0.460 sec
# =======================================
#
# ======== Epoch 82 =======
# Loss => train:0.89170, valid:1.07102, Elapsed time => 0.466 sec
# =======================================
#
# ======== Epoch 83 =======
# Loss => train:0.91626, valid:0.97785, Elapsed time => 0.451 sec
# =======================================
#
# ======== Epoch 84 =======
# Loss => train:0.89142, valid:0.98265, Elapsed time => 0.448 sec
# =======================================
#
# ======== Epoch 85 =======
# Loss => train:0.87766, valid:0.94309, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 86 =======
# Loss => train:0.87901, valid:0.95651, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 87 =======
# Loss => train:0.88101, valid:0.98327, Elapsed time => 0.478 sec
# =======================================
#
# ======== Epoch 88 =======
# Loss => train:0.86506, valid:1.02613, Elapsed time => 0.449 sec
# =======================================
#
# ======== Epoch 89 =======
# Loss => train:0.89153, valid:0.97138, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 90 =======
# Loss => train:0.89439, valid:0.97286, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 91 =======
# Loss => train:0.87767, valid:1.06403, Elapsed time => 0.452 sec
# =======================================
#
# ======== Epoch 92 =======
# Loss => train:0.87692, valid:0.95322, Elapsed time => 0.451 sec
# =======================================
#
# ======== Epoch 93 =======
# Loss => train:0.86740, valid:0.96677, Elapsed time => 0.644 sec
# =======================================
#
# ======== Epoch 94 =======
# Loss => train:0.86414, valid:0.93051, Elapsed time => 1.039 sec
# =======================================
#
# ======== Epoch 95 =======
# Loss => train:0.85806, valid:0.93209, Elapsed time => 1.098 sec
# =======================================
#
# ======== Epoch 96 =======
# Loss => train:0.86607, valid:0.95483, Elapsed time => 0.989 sec
# =======================================
#
# ======== Epoch 97 =======
# Loss => train:0.85317, valid:0.92842, Elapsed time => 0.847 sec
# =======================================
#
# ======== Epoch 98 =======
# Loss => train:0.85845, valid:0.97484, Elapsed time => 0.862 sec
# =======================================
#
# ======== Epoch 99 =======
# Loss => train:0.87938, valid:1.06490, Elapsed time => 0.890 sec
# =======================================
#
# ======== Epoch 100 =======
# Loss => train:0.89559, valid:0.94863, Elapsed time => 0.786 sec
# =======================================
#
# ======== Epoch 101 =======
# Loss => train:0.85731, valid:0.94272, Elapsed time => 0.794 sec
# =======================================
#
# ======== Epoch 102 =======
# Loss => train:0.86460, valid:0.94000, Elapsed time => 0.909 sec
# =======================================
#
# ======== Epoch 103 =======
# Loss => train:0.89716, valid:0.95159, Elapsed time => 0.885 sec
# =======================================
#
# ======== Epoch 104 =======
# Loss => train:0.88942, valid:0.96898, Elapsed time => 0.847 sec
# =======================================
#
# ======== Epoch 105 =======
# Loss => train:0.85791, valid:0.98736, Elapsed time => 0.946 sec
# =======================================
#
# ======== Epoch 106 =======
# Loss => train:0.85719, valid:0.95216, Elapsed time => 0.882 sec
# =======================================
#
# ======== Epoch 107 =======
# Loss => train:0.86316, valid:0.98699, Elapsed time => 0.837 sec
# =======================================
#
# ======== Epoch 108 =======
# Loss => train:0.87223, valid:0.92922, Elapsed time => 0.863 sec
# =======================================
#
# ======== Epoch 109 =======
# Loss => train:0.86881, valid:0.93218, Elapsed time => 0.898 sec
# =======================================
#
# ======== Epoch 110 =======
# Loss => train:0.84833, valid:0.94450, Elapsed time => 0.978 sec
# =======================================
#
# ======== Epoch 111 =======
# Loss => train:0.85591, valid:0.93574, Elapsed time => 0.928 sec
# =======================================
#
# ======== Epoch 112 =======
# Loss => train:0.85616, valid:0.97711, Elapsed time => 0.774 sec
# =======================================
#
# ======== Epoch 113 =======
# Loss => train:0.87038, valid:0.95332, Elapsed time => 0.915 sec
# =======================================
#
# ======== Epoch 114 =======
# Loss => train:0.85148, valid:0.97409, Elapsed time => 0.995 sec
# =======================================
#
# ======== Epoch 115 =======
# Loss => train:0.85267, valid:0.94281, Elapsed time => 0.898 sec
# =======================================
#
# ======== Epoch 116 =======
# Loss => train:0.85660, valid:0.93161, Elapsed time => 0.879 sec
# =======================================
#
# ======== Epoch 117 =======
# Loss => train:0.84890, valid:1.00996, Elapsed time => 0.857 sec
# =======================================
#
# ======== Epoch 118 =======
# Loss => train:0.85416, valid:1.04060, Elapsed time => 0.846 sec
# =======================================
#
# ======== Epoch 119 =======
# Loss => train:0.86053, valid:0.93118, Elapsed time => 0.896 sec
# =======================================
#
# ======== Epoch 120 =======
# Loss => train:0.83716, valid:0.92676, Elapsed time => 0.948 sec
# =======================================
#
# ======== Epoch 121 =======
# Loss => train:0.86282, valid:0.98712, Elapsed time => 0.828 sec
# =======================================
#
# ======== Epoch 122 =======
# Loss => train:0.90899, valid:0.94650, Elapsed time => 1.065 sec
# =======================================
#
# ======== Epoch 123 =======
# Loss => train:0.84681, valid:0.95179, Elapsed time => 0.939 sec
# =======================================
#
# ======== Epoch 124 =======
# Loss => train:0.84323, valid:0.93658, Elapsed time => 0.898 sec
# =======================================
#
# ======== Epoch 125 =======
# Loss => train:0.84456, valid:0.94025, Elapsed time => 0.920 sec
# =======================================
#
# ======== Epoch 126 =======
# Loss => train:0.84169, valid:0.93460, Elapsed time => 0.949 sec
# =======================================
#
# ======== Epoch 127 =======
# Loss => train:0.82668, valid:0.94583, Elapsed time => 0.848 sec
# =======================================
#
# ======== Epoch 128 =======
# Loss => train:0.84842, valid:1.04734, Elapsed time => 0.928 sec
# =======================================
#
# ======== Epoch 129 =======
# Loss => train:0.86944, valid:0.93992, Elapsed time => 0.994 sec
# =======================================
#
# ======== Epoch 130 =======
# Loss => train:0.82899, valid:1.00624, Elapsed time => 0.929 sec
# =======================================
#
# ======== Epoch 131 =======
# Loss => train:0.84851, valid:0.93145, Elapsed time => 0.911 sec
# =======================================
#
# ======== Epoch 132 =======
# Loss => train:0.83728, valid:1.05328, Elapsed time => 0.860 sec
# =======================================
#
# ======== Epoch 133 =======
# Loss => train:0.84668, valid:1.01851, Elapsed time => 0.890 sec
# =======================================
#
# ======== Epoch 134 =======
# Loss => train:0.83992, valid:0.98628, Elapsed time => 1.024 sec
# =======================================
#
# ======== Epoch 135 =======
# Loss => train:0.84172, valid:1.02476, Elapsed time => 1.031 sec
# =======================================
#
# ======== Epoch 136 =======
# Loss => train:0.85174, valid:0.93157, Elapsed time => 1.007 sec
# =======================================
#
# ======== Epoch 137 =======
# Loss => train:0.90466, valid:0.96313, Elapsed time => 0.862 sec
# =======================================
#
# ======== Epoch 138 =======
# Loss => train:0.84252, valid:1.03392, Elapsed time => 0.912 sec
# =======================================
#
# ======== Epoch 139 =======
# Loss => train:0.83015, valid:0.95615, Elapsed time => 0.855 sec
# =======================================
#
# ======== Epoch 140 =======
# Loss => train:0.84541, valid:0.94648, Elapsed time => 0.847 sec
# =======================================
#
# ======== Epoch 141 =======
# Loss => train:0.82009, valid:1.00794, Elapsed time => 0.743 sec
# =======================================
#
# ======== Epoch 142 =======
# Loss => train:0.85037, valid:0.98226, Elapsed time => 0.838 sec
# =======================================
#
# ======== Epoch 143 =======
# Loss => train:0.82885, valid:0.92745, Elapsed time => 0.975 sec
# =======================================
#
# ======== Epoch 144 =======
# Loss => train:0.86016, valid:0.99604, Elapsed time => 0.968 sec
# =======================================
#
# ======== Epoch 145 =======
# Loss => train:0.84243, valid:0.97309, Elapsed time => 1.140 sec
# =======================================
#
# ======== Epoch 146 =======
# Loss => train:0.83505, valid:0.95957, Elapsed time => 0.803 sec
# =======================================
#
# ======== Epoch 147 =======
# Loss => train:0.82649, valid:0.96200, Elapsed time => 0.860 sec
# =======================================
#
# ======== Epoch 148 =======
# Loss => train:0.82771, valid:0.95620, Elapsed time => 0.974 sec
# =======================================
#
# ======== Epoch 149 =======
# Loss => train:0.84562, valid:0.95752, Elapsed time => 0.994 sec
# =======================================
#
# ======== Epoch 150 =======
# Loss => train:0.83646, valid:0.95771, Elapsed time => 1.004 sec
# =======================================

# %% [markdown]
# # Learning Curve

# %%
import matplotlib.pyplot as plt 

plt.plot(train_loss_history)
plt.plot(valid_loss_history)
plt.axhline(y=min(valid_loss_history), color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# # Load best model

# %%
checkpoint = torch.load('./saved_model.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']

print(epoch, loss.item())
# Out:
# 120 0.9267611503601074

# %% [markdown]
# # Evaluation

# %%
prediction = model(X_test)
loss = criterion(prediction[:,0], y_test)

print(f"loss: {loss:.5f}")
# Out:
# loss: 1.61361

# %%
plt.figure(figsize=(15,6))
plt.plot(df_test.iloc[5:]['date'], y_test.detach().numpy())
plt.plot(df_test.iloc[5:]['date'], prediction[:,0].detach().numpy())
plt.show()
