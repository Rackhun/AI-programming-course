# %%
import torch
import torchvision

import pandas as pd
import numpy as np

# %% [markdown]
# # Seed

# %%
seed_number = 44

torch.manual_seed(seed_number)
torch.cuda.manual_seed(seed_number)
torch.cuda.manual_seed_all(seed_number) # if use multi-GPU
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(seed_number)
#random.seed(seed_number)

# %% [markdown]
# # Data Load

# %%
df = pd.read_csv('./seoul_107_air_quality_2001_2021.csv')

print(df.shape)
df.head()
# Out:
# (7266, 7)
#            dt       so2      no2      co        o3    pm10   pm2.5
# 0  2001-01-01  0.003542  0.03384  0.6543  0.004250   71.30   55.53
# 1  2001-01-02  0.001583  0.02759  0.5957  0.006084  428.00  160.60
# 2  2001-01-03  0.002125  0.02650  0.4458  0.006958   90.80   43.80
# 3  2001-01-04  0.003708  0.02870  0.5330  0.007416   76.94   42.10
# 4  2001-01-05  0.005165  0.05063  1.1580  0.000458   98.06   69.75

# %%
df.dtypes
# Out:
# dt        object
# so2      float64
# no2      float64
# co       float64
# o3       float64
# pm10     float64
# pm2.5    float64
# dtype: object

# %%
df['dt'] = pd.to_datetime(df['dt'])
df.dtypes
# Out:
# dt       datetime64[ns]
# so2             float64
# no2             float64
# co              float64
# o3              float64
# pm10            float64
# pm2.5           float64
# dtype: object

# %%
df_train = df[df['dt'].dt.year < 2019]
df_test  = df[df['dt'].dt.year >= 2019]

print(df_train.shape)
print(df_test.shape)
# Out:
# (6184, 7)
# (1082, 7)

# %%
X = df_train[['so2','no2','co','o3', 'pm10']].values
y = df_train['pm2.5'].values

X_test = df_test[['so2','no2','co','o3', 'pm10']].values
y_test = df_test['pm2.5'].values

print(X.shape, y.shape)
print(X_test.shape, y_test.shape)
# Out:
# (6184, 5) (6184,)
# (1082, 5) (1082,)

# %% [markdown]
# # Normalization

# %%
X_max = np.max(X, axis=0)
X_min = np.min(X, axis=0)

X      = (X      - X_min) / (X_max - X_min + 1e-10)
X_test = (X_test - X_min) / (X_max - X_min + 1e-10)

# %%
print(np.max(X), np.min(X))
print(np.max(X_test), np.min(X_test))
# Out:
# 0.999999999999913 0.0
# 1.2018348605476532 0.0

# %% [markdown]
# # Data organize (sequence)

# %%
sequence_length = 4

# %%
def make_sequence(data, sequence_length):
    data_seq = []
    for i in range(len(data)-sequence_length):
        data_seq.append(data[i:i+sequence_length])
            
    data_seq = np.stack(data_seq, axis=0)    
    return data_seq

# %%
X_seq = make_sequence(X, sequence_length=4)
y_seq = make_sequence(y, sequence_length=4)
X_test = make_sequence(X_test, sequence_length=4)
y_test = make_sequence(y_test, sequence_length=4)

print(X_seq.shape)
print(y_seq.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (6180, 4, 5)
# (6180, 4)
# (1078, 4, 5)
# (1078, 4)

# %% [markdown]
# # Split data

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X_seq, y_seq, test_size=0.2, random_state=seed_number)

print(X_train.shape, y_train.shape)
print(X_valid.shape, y_valid.shape)
# Out:
# (4944, 4, 5) (4944, 4)
# (1236, 4, 5) (1236, 4)

# %% [markdown]
# # Data loader

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

X_train = torch.FloatTensor(X_train).to(device=device)
X_valid = torch.FloatTensor(X_valid).to(device=device)
X_test  = torch.FloatTensor(X_test).to(device=device)

y_train = torch.FloatTensor(y_train).to(device=device)
y_valid = torch.FloatTensor(y_valid).to(device=device)
y_test  = torch.FloatTensor(y_test).to(device=device)
# Out:
# cpu

# %%
train_ds = torch.utils.data.TensorDataset(X_train, y_train)
valid_ds = torch.utils.data.TensorDataset(X_valid, y_valid)

train_loader = torch.utils.data.DataLoader(train_ds, batch_size=128, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_ds, batch_size=128, shuffle=False)

# %% [markdown]
# # Model (many to many)

# %%
class Net(torch.nn.Module):
    def __init__(self, n_input, n_hidden, n_layer, sequence_length):
        super(Net, self).__init__()
        
        self.n_input = n_input
        self.n_hidden = n_hidden
        self.n_layer = n_layer
        self.sequence_length = sequence_length
        
        # https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html
        self.LSTM = torch.nn.LSTM(
            n_input, n_hidden, n_layer, 
            bidirectional=False,
            batch_first=True
        )
        
        self.fully_connected_layer = torch.nn.Linear(n_hidden, 1)
        
    def forward(self, xb):
        h_init = torch.zeros(self.n_layer, xb.size()[0], self.n_hidden)
        c_init = torch.zeros(self.n_layer, xb.size()[0], self.n_hidden)
        out, _ = self.LSTM(xb, (h_init, c_init))
        
        out_seq = []
        for i in range(sequence_length):
            out_ = self.fully_connected_layer(out[:,i,:])
            out_seq.append(out_)
        out_seq = torch.stack(out_seq, dim=1)
        return out_seq

# %%
model = Net(
    n_input=5,
    n_hidden=64,
    n_layer=2,
    sequence_length=sequence_length,
).to(device)
print(model)
# Out:
# Net(
#   (LSTM): LSTM(5, 64, num_layers=2, batch_first=True)
#   (fully_connected_layer): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# # Cost function

# %%
criterion = torch.nn.MSELoss()

# %% [markdown]
# # Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # Training

# %%
import time 

is_train = True
epoch, early_stopping = 0, 0
train_loss_history, valid_loss_history = [], []

while is_train:
    start = time.time()
    train_loss, train_count = 0., 0.
    epoch += 1
    early_stopping += 1
    
    for xb, yb in train_loader:
        prediction = model(xb)
        loss = criterion(prediction[:,:,0], yb)
        train_loss += loss.item()*len(yb)
        train_count += len(yb)
        
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
    with torch.no_grad():
        valid_loss = 0
        valid_count = 0.
        
        for xb, yb in valid_loader:
            prediction = model(xb)
            valid_loss += criterion(prediction[:,:,0], yb)*len(yb)
            valid_count += len(yb)
        
    train_loss /= train_count
    valid_loss /= valid_count    
    
    train_loss_history.append(train_loss)
    valid_loss_history.append(valid_loss)
    
    if min(valid_loss_history) == valid_loss:
        early_stopping = 0
        
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': valid_loss,
        }, './saved_model.pt')
        
    if early_stopping == 15:
        is_train = False
            
    print(f"======== Epoch {epoch} =======")
    print(f"Loss => train:{train_loss:.5f}, valid:{valid_loss:.5f}, Elapsed time => {time.time()-start:.3f} sec")
    print("=======================================\n")
# Out:
# ======== Epoch 1 =======
# Loss => train:1261.62010, valid:1246.20886, Elapsed time => 0.500 sec
# =======================================
#
# ======== Epoch 2 =======
# Loss => train:1027.25291, valid:990.11334, Elapsed time => 0.446 sec
# =======================================
#
# ======== Epoch 3 =======
# Loss => train:842.18180, valid:841.57544, Elapsed time => 0.451 sec
# =======================================
#
# ======== Epoch 4 =======
# Loss => train:718.36438, valid:730.92993, Elapsed time => 0.430 sec
# =======================================
#
# ======== Epoch 5 =======
# Loss => train:627.01322, valid:651.15051, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 6 =======
# Loss => train:563.11625, valid:595.42987, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 7 =======
# Loss => train:519.11111, valid:556.48022, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 8 =======
# Loss => train:488.86715, valid:528.77167, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 9 =======
# Loss => train:467.97673, valid:509.66394, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 10 =======
# Loss => train:453.76803, valid:496.42203, Elapsed time => 0.447 sec
# =======================================
#
# ======== Epoch 11 =======
# Loss => train:444.27683, valid:487.11722, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 12 =======
# Loss => train:438.10391, valid:480.80765, Elapsed time => 0.430 sec
# =======================================
#
# ======== Epoch 13 =======
# Loss => train:434.08801, valid:476.75061, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 14 =======
# Loss => train:431.65555, valid:473.97852, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 15 =======
# Loss => train:430.16276, valid:472.21597, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 16 =======
# Loss => train:429.27117, valid:471.07144, Elapsed time => 0.420 sec
# =======================================
#
# ======== Epoch 17 =======
# Loss => train:428.80175, valid:470.14703, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 18 =======
# Loss => train:428.45572, valid:469.74271, Elapsed time => 0.414 sec
# =======================================
#
# ======== Epoch 19 =======
# Loss => train:428.28764, valid:469.45673, Elapsed time => 0.438 sec
# =======================================
#
# ======== Epoch 20 =======
# Loss => train:428.21288, valid:469.10239, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 21 =======
# Loss => train:428.11469, valid:469.05750, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 22 =======
# Loss => train:428.09970, valid:468.86523, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 23 =======
# Loss => train:428.05512, valid:468.83728, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 24 =======
# Loss => train:428.03320, valid:468.76141, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 25 =======
# Loss => train:428.02570, valid:468.69504, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 26 =======
# Loss => train:428.01067, valid:468.74283, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 27 =======
# Loss => train:427.98085, valid:468.60675, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 28 =======
# Loss => train:427.96809, valid:468.60306, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 29 =======
# Loss => train:427.97374, valid:468.65094, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 30 =======
# Loss => train:427.96567, valid:468.54803, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 31 =======
# Loss => train:427.93191, valid:468.49661, Elapsed time => 0.451 sec
# =======================================
#
# ======== Epoch 32 =======
# Loss => train:427.90087, valid:468.58682, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 33 =======
# Loss => train:427.89711, valid:468.47336, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 34 =======
# Loss => train:427.84852, valid:468.49854, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 35 =======
# Loss => train:427.83717, valid:468.48306, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 36 =======
# Loss => train:427.80514, valid:468.49814, Elapsed time => 0.414 sec
# =======================================
#
# ======== Epoch 37 =======
# Loss => train:427.67950, valid:468.32907, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 38 =======
# Loss => train:427.50306, valid:468.14032, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 39 =======
# Loss => train:427.35810, valid:467.96683, Elapsed time => 0.450 sec
# =======================================
#
# ======== Epoch 40 =======
# Loss => train:426.93958, valid:467.73331, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 41 =======
# Loss => train:426.40349, valid:467.25339, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 42 =======
# Loss => train:426.02016, valid:466.90686, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 43 =======
# Loss => train:425.37358, valid:466.46060, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 44 =======
# Loss => train:424.42906, valid:465.65271, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 45 =======
# Loss => train:423.54444, valid:464.69696, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 46 =======
# Loss => train:422.49946, valid:463.73508, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 47 =======
# Loss => train:420.83367, valid:462.62405, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 48 =======
# Loss => train:419.26941, valid:461.54031, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 49 =======
# Loss => train:417.14459, valid:458.44391, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 50 =======
# Loss => train:414.53623, valid:456.35962, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 51 =======
# Loss => train:410.20184, valid:447.20883, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 52 =======
# Loss => train:395.75925, valid:428.07990, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 53 =======
# Loss => train:355.74370, valid:372.97147, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 54 =======
# Loss => train:309.47656, valid:340.34283, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 55 =======
# Loss => train:284.48725, valid:324.26822, Elapsed time => 0.442 sec
# =======================================
#
# ======== Epoch 56 =======
# Loss => train:268.98165, valid:303.67966, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 57 =======
# Loss => train:253.36991, valid:288.09039, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 58 =======
# Loss => train:240.34601, valid:277.66895, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 59 =======
# Loss => train:228.50066, valid:263.32520, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 60 =======
# Loss => train:216.19238, valid:250.84555, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 61 =======
# Loss => train:206.13193, valid:240.31570, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 62 =======
# Loss => train:196.13410, valid:230.96048, Elapsed time => 0.414 sec
# =======================================
#
# ======== Epoch 63 =======
# Loss => train:189.07256, valid:224.70589, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 64 =======
# Loss => train:180.30705, valid:215.85133, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 65 =======
# Loss => train:172.45994, valid:206.66815, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 66 =======
# Loss => train:166.77258, valid:199.73778, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 67 =======
# Loss => train:161.95403, valid:195.47697, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 68 =======
# Loss => train:154.57593, valid:188.96860, Elapsed time => 0.426 sec
# =======================================
#
# ======== Epoch 69 =======
# Loss => train:149.58679, valid:183.97421, Elapsed time => 0.425 sec
# =======================================
#
# ======== Epoch 70 =======
# Loss => train:144.38428, valid:179.08662, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 71 =======
# Loss => train:141.17800, valid:173.83937, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 72 =======
# Loss => train:136.82925, valid:171.58188, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 73 =======
# Loss => train:133.91554, valid:167.46294, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 74 =======
# Loss => train:130.61798, valid:164.68398, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 75 =======
# Loss => train:127.95627, valid:163.22063, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 76 =======
# Loss => train:125.50101, valid:158.79195, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 77 =======
# Loss => train:123.24863, valid:159.48283, Elapsed time => 0.420 sec
# =======================================
#
# ======== Epoch 78 =======
# Loss => train:121.47828, valid:154.59814, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 79 =======
# Loss => train:119.60961, valid:154.07828, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 80 =======
# Loss => train:120.03377, valid:151.38750, Elapsed time => 0.428 sec
# =======================================
#
# ======== Epoch 81 =======
# Loss => train:117.58192, valid:150.41484, Elapsed time => 0.413 sec
# =======================================
#
# ======== Epoch 82 =======
# Loss => train:115.97754, valid:148.19696, Elapsed time => 0.438 sec
# =======================================
#
# ======== Epoch 83 =======
# Loss => train:113.99869, valid:147.73405, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 84 =======
# Loss => train:113.02039, valid:146.25778, Elapsed time => 0.441 sec
# =======================================
#
# ======== Epoch 85 =======
# Loss => train:112.29604, valid:145.25226, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 86 =======
# Loss => train:112.33388, valid:143.11940, Elapsed time => 0.445 sec
# =======================================
#
# ======== Epoch 87 =======
# Loss => train:111.56207, valid:142.06641, Elapsed time => 0.442 sec
# =======================================
#
# ======== Epoch 88 =======
# Loss => train:108.88904, valid:141.73404, Elapsed time => 0.430 sec
# =======================================
#
# ======== Epoch 89 =======
# Loss => train:107.95363, valid:139.56018, Elapsed time => 0.441 sec
# =======================================
#
# ======== Epoch 90 =======
# Loss => train:108.91101, valid:139.86737, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 91 =======
# Loss => train:106.89618, valid:138.46771, Elapsed time => 0.443 sec
# =======================================
#
# ======== Epoch 92 =======
# Loss => train:105.77039, valid:138.20038, Elapsed time => 0.438 sec
# =======================================
#
# ======== Epoch 93 =======
# Loss => train:105.21424, valid:136.47922, Elapsed time => 0.440 sec
# =======================================
#
# ======== Epoch 94 =======
# Loss => train:104.26721, valid:134.93924, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 95 =======
# Loss => train:103.17306, valid:134.17067, Elapsed time => 0.449 sec
# =======================================
#
# ======== Epoch 96 =======
# Loss => train:102.05009, valid:134.25409, Elapsed time => 0.420 sec
# =======================================
#
# ======== Epoch 97 =======
# Loss => train:101.31329, valid:133.33101, Elapsed time => 0.430 sec
# =======================================
#
# ======== Epoch 98 =======
# Loss => train:101.44002, valid:135.10829, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 99 =======
# Loss => train:100.09668, valid:131.88802, Elapsed time => 0.450 sec
# =======================================
#
# ======== Epoch 100 =======
# Loss => train:99.22192, valid:130.09769, Elapsed time => 0.447 sec
# =======================================
#
# ======== Epoch 101 =======
# Loss => train:98.91337, valid:132.26996, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 102 =======
# Loss => train:98.88619, valid:128.81889, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 103 =======
# Loss => train:97.46040, valid:131.35695, Elapsed time => 0.631 sec
# =======================================
#
# ======== Epoch 104 =======
# Loss => train:97.05520, valid:127.04541, Elapsed time => 0.452 sec
# =======================================
#
# ======== Epoch 105 =======
# Loss => train:95.72128, valid:126.30109, Elapsed time => 0.476 sec
# =======================================
#
# ======== Epoch 106 =======
# Loss => train:95.23241, valid:125.98645, Elapsed time => 0.442 sec
# =======================================
#
# ======== Epoch 107 =======
# Loss => train:95.28718, valid:125.57121, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 108 =======
# Loss => train:95.24376, valid:124.46326, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 109 =======
# Loss => train:93.27000, valid:126.08557, Elapsed time => 0.452 sec
# =======================================
#
# ======== Epoch 110 =======
# Loss => train:93.02403, valid:122.54346, Elapsed time => 0.449 sec
# =======================================
#
# ======== Epoch 111 =======
# Loss => train:92.66807, valid:121.85370, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 112 =======
# Loss => train:91.87382, valid:122.14035, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 113 =======
# Loss => train:91.14853, valid:121.23138, Elapsed time => 0.413 sec
# =======================================
#
# ======== Epoch 114 =======
# Loss => train:90.37687, valid:121.46269, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 115 =======
# Loss => train:90.13793, valid:121.86136, Elapsed time => 0.414 sec
# =======================================
#
# ======== Epoch 116 =======
# Loss => train:89.34441, valid:119.64280, Elapsed time => 0.442 sec
# =======================================
#
# ======== Epoch 117 =======
# Loss => train:89.04616, valid:119.60995, Elapsed time => 0.459 sec
# =======================================
#
# ======== Epoch 118 =======
# Loss => train:88.38720, valid:119.20751, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 119 =======
# Loss => train:89.15439, valid:117.33971, Elapsed time => 0.458 sec
# =======================================
#
# ======== Epoch 120 =======
# Loss => train:87.42957, valid:117.83729, Elapsed time => 0.448 sec
# =======================================
#
# ======== Epoch 121 =======
# Loss => train:87.25765, valid:116.18113, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 122 =======
# Loss => train:86.46160, valid:116.28871, Elapsed time => 0.441 sec
# =======================================
#
# ======== Epoch 123 =======
# Loss => train:86.18110, valid:115.47654, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 124 =======
# Loss => train:85.79195, valid:115.89592, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 125 =======
# Loss => train:85.39297, valid:115.63276, Elapsed time => 0.450 sec
# =======================================
#
# ======== Epoch 126 =======
# Loss => train:84.77494, valid:115.62265, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 127 =======
# Loss => train:85.20411, valid:113.02895, Elapsed time => 0.476 sec
# =======================================
#
# ======== Epoch 128 =======
# Loss => train:84.48747, valid:117.01851, Elapsed time => 0.455 sec
# =======================================
#
# ======== Epoch 129 =======
# Loss => train:85.04473, valid:112.71803, Elapsed time => 0.443 sec
# =======================================
#
# ======== Epoch 130 =======
# Loss => train:83.83135, valid:112.34914, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 131 =======
# Loss => train:82.86290, valid:112.70358, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 132 =======
# Loss => train:82.85430, valid:111.83588, Elapsed time => 0.445 sec
# =======================================
#
# ======== Epoch 133 =======
# Loss => train:82.02490, valid:110.97389, Elapsed time => 0.441 sec
# =======================================
#
# ======== Epoch 134 =======
# Loss => train:83.56516, valid:115.63876, Elapsed time => 0.482 sec
# =======================================
#
# ======== Epoch 135 =======
# Loss => train:84.70096, valid:112.57297, Elapsed time => 0.456 sec
# =======================================
#
# ======== Epoch 136 =======
# Loss => train:81.79846, valid:110.02958, Elapsed time => 0.448 sec
# =======================================
#
# ======== Epoch 137 =======
# Loss => train:80.51725, valid:109.22002, Elapsed time => 0.506 sec
# =======================================
#
# ======== Epoch 138 =======
# Loss => train:81.11896, valid:108.85021, Elapsed time => 0.458 sec
# =======================================
#
# ======== Epoch 139 =======
# Loss => train:80.48854, valid:108.32289, Elapsed time => 0.469 sec
# =======================================
#
# ======== Epoch 140 =======
# Loss => train:79.95566, valid:107.95290, Elapsed time => 0.453 sec
# =======================================
#
# ======== Epoch 141 =======
# Loss => train:79.17519, valid:108.39028, Elapsed time => 0.447 sec
# =======================================
#
# ======== Epoch 142 =======
# Loss => train:80.04147, valid:107.92805, Elapsed time => 0.444 sec
# =======================================
#
# ======== Epoch 143 =======
# Loss => train:78.61251, valid:107.20351, Elapsed time => 0.537 sec
# =======================================
#
# ======== Epoch 144 =======
# Loss => train:78.31446, valid:106.89257, Elapsed time => 0.472 sec
# =======================================
#
# ======== Epoch 145 =======
# Loss => train:78.34279, valid:106.66454, Elapsed time => 0.474 sec
# =======================================
#
# ======== Epoch 146 =======
# Loss => train:78.28863, valid:107.83727, Elapsed time => 0.464 sec
# =======================================
#
# ======== Epoch 147 =======
# Loss => train:77.79861, valid:106.14834, Elapsed time => 0.467 sec
# =======================================
#
# ======== Epoch 148 =======
# Loss => train:77.06838, valid:105.79607, Elapsed time => 0.489 sec
# =======================================
#
# ======== Epoch 149 =======
# Loss => train:77.40834, valid:106.35989, Elapsed time => 0.450 sec
# =======================================
#
# ======== Epoch 150 =======
# Loss => train:78.61617, valid:105.97720, Elapsed time => 0.468 sec
# =======================================
#
# ======== Epoch 151 =======
# Loss => train:76.92362, valid:105.72450, Elapsed time => 0.462 sec
# =======================================
#
# ======== Epoch 152 =======
# Loss => train:75.99644, valid:104.58537, Elapsed time => 0.457 sec
# =======================================
#
# ======== Epoch 153 =======
# Loss => train:75.85428, valid:104.19319, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 154 =======
# Loss => train:75.42531, valid:103.56303, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 155 =======
# Loss => train:76.62513, valid:103.26196, Elapsed time => 0.448 sec
# =======================================
#
# ======== Epoch 156 =======
# Loss => train:75.54621, valid:104.20886, Elapsed time => 0.440 sec
# =======================================
#
# ======== Epoch 157 =======
# Loss => train:75.25053, valid:102.36740, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 158 =======
# Loss => train:74.85623, valid:102.68956, Elapsed time => 0.428 sec
# =======================================
#
# ======== Epoch 159 =======
# Loss => train:74.20937, valid:102.85195, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 160 =======
# Loss => train:73.73039, valid:101.69939, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 161 =======
# Loss => train:73.57971, valid:104.20834, Elapsed time => 0.452 sec
# =======================================
#
# ======== Epoch 162 =======
# Loss => train:74.21822, valid:101.09438, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 163 =======
# Loss => train:73.54116, valid:101.95483, Elapsed time => 0.446 sec
# =======================================
#
# ======== Epoch 164 =======
# Loss => train:73.40337, valid:101.39439, Elapsed time => 0.442 sec
# =======================================
#
# ======== Epoch 165 =======
# Loss => train:73.20891, valid:100.31297, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 166 =======
# Loss => train:73.07100, valid:100.01543, Elapsed time => 0.448 sec
# =======================================
#
# ======== Epoch 167 =======
# Loss => train:72.10559, valid:99.98374, Elapsed time => 0.442 sec
# =======================================
#
# ======== Epoch 168 =======
# Loss => train:72.15799, valid:99.41327, Elapsed time => 0.457 sec
# =======================================
#
# ======== Epoch 169 =======
# Loss => train:72.42486, valid:99.60571, Elapsed time => 0.452 sec
# =======================================
#
# ======== Epoch 170 =======
# Loss => train:71.44674, valid:99.59203, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 171 =======
# Loss => train:71.79997, valid:99.21539, Elapsed time => 0.449 sec
# =======================================
#
# ======== Epoch 172 =======
# Loss => train:71.56714, valid:98.75379, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 173 =======
# Loss => train:70.80509, valid:98.72285, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 174 =======
# Loss => train:71.31004, valid:98.73907, Elapsed time => 0.449 sec
# =======================================
#
# ======== Epoch 175 =======
# Loss => train:71.12565, valid:100.49268, Elapsed time => 0.425 sec
# =======================================
#
# ======== Epoch 176 =======
# Loss => train:71.16312, valid:97.68275, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 177 =======
# Loss => train:70.34684, valid:97.35564, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 178 =======
# Loss => train:69.89787, valid:97.32225, Elapsed time => 0.430 sec
# =======================================
#
# ======== Epoch 179 =======
# Loss => train:69.51086, valid:98.79992, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 180 =======
# Loss => train:69.84005, valid:97.33019, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 181 =======
# Loss => train:69.54572, valid:98.10892, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 182 =======
# Loss => train:69.44009, valid:96.62806, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 183 =======
# Loss => train:69.10753, valid:96.05502, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 184 =======
# Loss => train:68.95178, valid:96.65202, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 185 =======
# Loss => train:68.64499, valid:96.03418, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 186 =======
# Loss => train:68.12923, valid:95.42177, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 187 =======
# Loss => train:69.25143, valid:99.35895, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 188 =======
# Loss => train:68.56259, valid:95.14339, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 189 =======
# Loss => train:68.36107, valid:95.90588, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 190 =======
# Loss => train:68.68319, valid:96.36101, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 191 =======
# Loss => train:67.77154, valid:94.76376, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 192 =======
# Loss => train:67.31828, valid:94.33607, Elapsed time => 0.449 sec
# =======================================
#
# ======== Epoch 193 =======
# Loss => train:67.40533, valid:94.77596, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 194 =======
# Loss => train:67.89899, valid:97.06804, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 195 =======
# Loss => train:67.54707, valid:95.11610, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 196 =======
# Loss => train:66.74605, valid:93.57012, Elapsed time => 0.440 sec
# =======================================
#
# ======== Epoch 197 =======
# Loss => train:66.62084, valid:93.71206, Elapsed time => 0.426 sec
# =======================================
#
# ======== Epoch 198 =======
# Loss => train:66.20947, valid:93.56659, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 199 =======
# Loss => train:66.72657, valid:93.61083, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 200 =======
# Loss => train:67.23910, valid:93.30122, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 201 =======
# Loss => train:66.26805, valid:92.92637, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 202 =======
# Loss => train:65.80088, valid:92.47379, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 203 =======
# Loss => train:65.80321, valid:93.50749, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 204 =======
# Loss => train:66.01003, valid:93.32497, Elapsed time => 0.420 sec
# =======================================
#
# ======== Epoch 205 =======
# Loss => train:65.87364, valid:92.90693, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 206 =======
# Loss => train:65.17834, valid:92.03648, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 207 =======
# Loss => train:65.39649, valid:92.43941, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 208 =======
# Loss => train:65.40053, valid:91.80826, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 209 =======
# Loss => train:64.75051, valid:92.09290, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 210 =======
# Loss => train:64.97369, valid:91.71707, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 211 =======
# Loss => train:64.29666, valid:91.80648, Elapsed time => 0.414 sec
# =======================================
#
# ======== Epoch 212 =======
# Loss => train:64.31955, valid:91.48963, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 213 =======
# Loss => train:63.97329, valid:91.50409, Elapsed time => 0.413 sec
# =======================================
#
# ======== Epoch 214 =======
# Loss => train:63.86047, valid:90.98223, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 215 =======
# Loss => train:64.22050, valid:91.60287, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 216 =======
# Loss => train:65.46585, valid:90.18946, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 217 =======
# Loss => train:64.30833, valid:90.82089, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 218 =======
# Loss => train:63.74345, valid:90.85590, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 219 =======
# Loss => train:63.32862, valid:89.97645, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 220 =======
# Loss => train:64.14159, valid:89.59028, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 221 =======
# Loss => train:63.01491, valid:89.65363, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 222 =======
# Loss => train:62.58626, valid:91.34547, Elapsed time => 0.412 sec
# =======================================
#
# ======== Epoch 223 =======
# Loss => train:62.64060, valid:89.90068, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 224 =======
# Loss => train:62.77304, valid:91.29749, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 225 =======
# Loss => train:62.47972, valid:90.67267, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 226 =======
# Loss => train:62.31925, valid:88.89478, Elapsed time => 0.414 sec
# =======================================
#
# ======== Epoch 227 =======
# Loss => train:62.00433, valid:88.77909, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 228 =======
# Loss => train:62.17819, valid:88.55235, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 229 =======
# Loss => train:62.20119, valid:89.90839, Elapsed time => 0.425 sec
# =======================================
#
# ======== Epoch 230 =======
# Loss => train:61.64806, valid:88.38760, Elapsed time => 0.425 sec
# =======================================
#
# ======== Epoch 231 =======
# Loss => train:61.51172, valid:88.39312, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 232 =======
# Loss => train:61.13845, valid:88.11820, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 233 =======
# Loss => train:61.63665, valid:88.73654, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 234 =======
# Loss => train:61.65467, valid:88.20080, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 235 =======
# Loss => train:61.05879, valid:87.65590, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 236 =======
# Loss => train:60.98294, valid:88.45454, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 237 =======
# Loss => train:60.43808, valid:87.60133, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 238 =======
# Loss => train:60.48949, valid:87.06310, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 239 =======
# Loss => train:60.37357, valid:87.86304, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 240 =======
# Loss => train:60.40552, valid:87.85932, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 241 =======
# Loss => train:60.61345, valid:87.36820, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 242 =======
# Loss => train:60.13319, valid:87.17442, Elapsed time => 0.430 sec
# =======================================
#
# ======== Epoch 243 =======
# Loss => train:60.86976, valid:86.90580, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 244 =======
# Loss => train:59.65436, valid:87.08678, Elapsed time => 0.425 sec
# =======================================
#
# ======== Epoch 245 =======
# Loss => train:59.46028, valid:87.81499, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 246 =======
# Loss => train:59.82153, valid:87.07858, Elapsed time => 0.422 sec
# =======================================
#
# ======== Epoch 247 =======
# Loss => train:59.32742, valid:87.51042, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 248 =======
# Loss => train:59.47385, valid:86.28472, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 249 =======
# Loss => train:59.77519, valid:88.95191, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 250 =======
# Loss => train:59.36163, valid:86.79321, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 251 =======
# Loss => train:58.98692, valid:86.53433, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 252 =======
# Loss => train:58.97512, valid:86.22807, Elapsed time => 0.426 sec
# =======================================
#
# ======== Epoch 253 =======
# Loss => train:59.00462, valid:86.20928, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 254 =======
# Loss => train:58.92136, valid:85.99966, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 255 =======
# Loss => train:58.91368, valid:85.46281, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 256 =======
# Loss => train:58.83398, valid:85.71680, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 257 =======
# Loss => train:58.50058, valid:86.12233, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 258 =======
# Loss => train:57.84202, valid:85.30540, Elapsed time => 0.425 sec
# =======================================
#
# ======== Epoch 259 =======
# Loss => train:58.06086, valid:85.28404, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 260 =======
# Loss => train:57.95650, valid:85.35262, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 261 =======
# Loss => train:58.00449, valid:85.43517, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 262 =======
# Loss => train:58.34753, valid:85.06767, Elapsed time => 0.414 sec
# =======================================
#
# ======== Epoch 263 =======
# Loss => train:58.82471, valid:85.25150, Elapsed time => 0.440 sec
# =======================================
#
# ======== Epoch 264 =======
# Loss => train:57.43556, valid:84.59369, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 265 =======
# Loss => train:57.61068, valid:84.49281, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 266 =======
# Loss => train:57.55984, valid:86.57755, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 267 =======
# Loss => train:57.39913, valid:84.85317, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 268 =======
# Loss => train:57.33869, valid:83.99088, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 269 =======
# Loss => train:56.73794, valid:84.63349, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 270 =======
# Loss => train:57.18239, valid:86.70898, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 271 =======
# Loss => train:57.24568, valid:83.94546, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 272 =======
# Loss => train:56.53320, valid:85.04437, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 273 =======
# Loss => train:56.45279, valid:84.10683, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 274 =======
# Loss => train:56.15967, valid:83.55985, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 275 =======
# Loss => train:55.97926, valid:83.46310, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 276 =======
# Loss => train:56.54046, valid:85.60928, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 277 =======
# Loss => train:56.42921, valid:84.73207, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 278 =======
# Loss => train:56.14334, valid:84.01144, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 279 =======
# Loss => train:56.34835, valid:83.73491, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 280 =======
# Loss => train:55.76451, valid:84.16230, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 281 =======
# Loss => train:55.58257, valid:82.81384, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 282 =======
# Loss => train:55.42211, valid:82.97054, Elapsed time => 0.425 sec
# =======================================
#
# ======== Epoch 283 =======
# Loss => train:55.01615, valid:83.24516, Elapsed time => 0.421 sec
# =======================================
#
# ======== Epoch 284 =======
# Loss => train:55.60633, valid:83.08292, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 285 =======
# Loss => train:54.93652, valid:82.66840, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 286 =======
# Loss => train:55.02639, valid:83.11216, Elapsed time => 0.428 sec
# =======================================
#
# ======== Epoch 287 =======
# Loss => train:54.93876, valid:83.59297, Elapsed time => 0.422 sec
# =======================================
#
# ======== Epoch 288 =======
# Loss => train:55.07374, valid:82.78458, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 289 =======
# Loss => train:54.50402, valid:82.23028, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 290 =======
# Loss => train:54.46785, valid:82.43863, Elapsed time => 0.428 sec
# =======================================
#
# ======== Epoch 291 =======
# Loss => train:54.58190, valid:82.59451, Elapsed time => 0.422 sec
# =======================================
#
# ======== Epoch 292 =======
# Loss => train:54.29545, valid:82.48422, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 293 =======
# Loss => train:54.26682, valid:82.04491, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 294 =======
# Loss => train:54.49598, valid:82.31115, Elapsed time => 0.450 sec
# =======================================
#
# ======== Epoch 295 =======
# Loss => train:53.96324, valid:82.04729, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 296 =======
# Loss => train:54.31640, valid:82.59948, Elapsed time => 0.450 sec
# =======================================
#
# ======== Epoch 297 =======
# Loss => train:55.42119, valid:83.02182, Elapsed time => 0.450 sec
# =======================================
#
# ======== Epoch 298 =======
# Loss => train:54.06210, valid:81.76901, Elapsed time => 0.454 sec
# =======================================
#
# ======== Epoch 299 =======
# Loss => train:54.11120, valid:81.76026, Elapsed time => 0.448 sec
# =======================================
#
# ======== Epoch 300 =======
# Loss => train:53.83190, valid:82.11605, Elapsed time => 0.464 sec
# =======================================
#
# ======== Epoch 301 =======
# Loss => train:53.12321, valid:83.14629, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 302 =======
# Loss => train:53.63387, valid:82.56670, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 303 =======
# Loss => train:53.48677, valid:81.73763, Elapsed time => 0.453 sec
# =======================================
#
# ======== Epoch 304 =======
# Loss => train:53.32359, valid:82.11511, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 305 =======
# Loss => train:53.83584, valid:81.43587, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 306 =======
# Loss => train:52.90911, valid:81.84946, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 307 =======
# Loss => train:52.78777, valid:81.29274, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 308 =======
# Loss => train:52.53670, valid:81.23741, Elapsed time => 0.456 sec
# =======================================
#
# ======== Epoch 309 =======
# Loss => train:52.68099, valid:81.59485, Elapsed time => 0.425 sec
# =======================================
#
# ======== Epoch 310 =======
# Loss => train:52.39494, valid:80.98686, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 311 =======
# Loss => train:52.31470, valid:80.63793, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 312 =======
# Loss => train:52.65994, valid:80.77589, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 313 =======
# Loss => train:52.12738, valid:81.62181, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 314 =======
# Loss => train:51.97397, valid:81.61778, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 315 =======
# Loss => train:51.86623, valid:81.47112, Elapsed time => 0.422 sec
# =======================================
#
# ======== Epoch 316 =======
# Loss => train:52.19696, valid:81.04537, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 317 =======
# Loss => train:51.69571, valid:80.94222, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 318 =======
# Loss => train:51.57426, valid:80.71298, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 319 =======
# Loss => train:52.19236, valid:81.57047, Elapsed time => 0.411 sec
# =======================================
#
# ======== Epoch 320 =======
# Loss => train:51.91725, valid:80.54592, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 321 =======
# Loss => train:51.60889, valid:80.57451, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 322 =======
# Loss => train:51.59567, valid:80.21494, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 323 =======
# Loss => train:51.66247, valid:81.30234, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 324 =======
# Loss => train:50.99359, valid:79.98333, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 325 =======
# Loss => train:50.98469, valid:82.27745, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 326 =======
# Loss => train:51.13924, valid:80.41611, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 327 =======
# Loss => train:51.17417, valid:80.01081, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 328 =======
# Loss => train:50.70631, valid:81.28531, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 329 =======
# Loss => train:50.62458, valid:80.95215, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 330 =======
# Loss => train:51.81055, valid:83.76797, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 331 =======
# Loss => train:50.83773, valid:80.86396, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 332 =======
# Loss => train:50.32157, valid:80.24405, Elapsed time => 0.407 sec
# =======================================
#
# ======== Epoch 333 =======
# Loss => train:50.35013, valid:79.60703, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 334 =======
# Loss => train:50.31363, valid:81.28780, Elapsed time => 0.414 sec
# =======================================
#
# ======== Epoch 335 =======
# Loss => train:50.57863, valid:79.64449, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 336 =======
# Loss => train:50.05866, valid:79.99214, Elapsed time => 0.422 sec
# =======================================
#
# ======== Epoch 337 =======
# Loss => train:49.87894, valid:80.24477, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 338 =======
# Loss => train:49.68152, valid:80.06406, Elapsed time => 0.428 sec
# =======================================
#
# ======== Epoch 339 =======
# Loss => train:49.75231, valid:80.02129, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 340 =======
# Loss => train:49.72741, valid:80.99245, Elapsed time => 0.428 sec
# =======================================
#
# ======== Epoch 341 =======
# Loss => train:49.39449, valid:80.25979, Elapsed time => 0.456 sec
# =======================================
#
# ======== Epoch 342 =======
# Loss => train:50.15694, valid:79.71206, Elapsed time => 0.453 sec
# =======================================
#
# ======== Epoch 343 =======
# Loss => train:49.53942, valid:80.26327, Elapsed time => 0.438 sec
# =======================================
#
# ======== Epoch 344 =======
# Loss => train:49.11340, valid:79.00321, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 345 =======
# Loss => train:49.39193, valid:79.39500, Elapsed time => 0.450 sec
# =======================================
#
# ======== Epoch 346 =======
# Loss => train:49.20299, valid:79.66366, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 347 =======
# Loss => train:48.93714, valid:79.77154, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 348 =======
# Loss => train:48.77168, valid:79.07008, Elapsed time => 0.474 sec
# =======================================
#
# ======== Epoch 349 =======
# Loss => train:48.66135, valid:80.05630, Elapsed time => 0.430 sec
# =======================================
#
# ======== Epoch 350 =======
# Loss => train:48.80171, valid:79.18837, Elapsed time => 0.462 sec
# =======================================
#
# ======== Epoch 351 =======
# Loss => train:48.65547, valid:79.60058, Elapsed time => 0.454 sec
# =======================================
#
# ======== Epoch 352 =======
# Loss => train:49.15456, valid:79.67296, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 353 =======
# Loss => train:48.56747, valid:78.99672, Elapsed time => 0.456 sec
# =======================================
#
# ======== Epoch 354 =======
# Loss => train:48.62611, valid:80.17280, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 355 =======
# Loss => train:48.45306, valid:79.40348, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 356 =======
# Loss => train:48.90134, valid:79.13814, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 357 =======
# Loss => train:48.30203, valid:79.01909, Elapsed time => 0.430 sec
# =======================================
#
# ======== Epoch 358 =======
# Loss => train:47.92174, valid:78.68373, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 359 =======
# Loss => train:47.89472, valid:79.98067, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 360 =======
# Loss => train:48.10562, valid:78.83755, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 361 =======
# Loss => train:47.63328, valid:78.80515, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 362 =======
# Loss => train:47.78520, valid:78.87157, Elapsed time => 0.420 sec
# =======================================
#
# ======== Epoch 363 =======
# Loss => train:47.64214, valid:79.07402, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 364 =======
# Loss => train:48.23269, valid:78.63611, Elapsed time => 0.418 sec
# =======================================
#
# ======== Epoch 365 =======
# Loss => train:47.67722, valid:78.27552, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 366 =======
# Loss => train:47.18009, valid:78.34462, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 367 =======
# Loss => train:47.29090, valid:78.68439, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 368 =======
# Loss => train:47.49776, valid:78.91884, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 369 =======
# Loss => train:47.57380, valid:79.05228, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 370 =======
# Loss => train:47.30779, valid:78.87440, Elapsed time => 0.416 sec
# =======================================
#
# ======== Epoch 371 =======
# Loss => train:47.24725, valid:78.61728, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 372 =======
# Loss => train:47.05776, valid:78.87875, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 373 =======
# Loss => train:46.71860, valid:79.26398, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 374 =======
# Loss => train:46.62867, valid:78.30795, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 375 =======
# Loss => train:46.69588, valid:78.39380, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 376 =======
# Loss => train:46.38169, valid:78.53410, Elapsed time => 0.420 sec
# =======================================
#
# ======== Epoch 377 =======
# Loss => train:46.88840, valid:78.17429, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 378 =======
# Loss => train:46.78798, valid:78.62967, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 379 =======
# Loss => train:46.15043, valid:79.51620, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 380 =======
# Loss => train:46.37191, valid:78.28479, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 381 =======
# Loss => train:46.12196, valid:78.78407, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 382 =======
# Loss => train:46.24750, valid:79.60363, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 383 =======
# Loss => train:46.52141, valid:78.45690, Elapsed time => 0.411 sec
# =======================================
#
# ======== Epoch 384 =======
# Loss => train:46.07087, valid:78.46735, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 385 =======
# Loss => train:46.01224, valid:78.06142, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 386 =======
# Loss => train:45.86048, valid:78.68169, Elapsed time => 0.428 sec
# =======================================
#
# ======== Epoch 387 =======
# Loss => train:45.85905, valid:78.35793, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 388 =======
# Loss => train:45.84474, valid:80.26228, Elapsed time => 0.413 sec
# =======================================
#
# ======== Epoch 389 =======
# Loss => train:45.65622, valid:78.23051, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 390 =======
# Loss => train:45.66273, valid:78.43527, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 391 =======
# Loss => train:45.52869, valid:78.13785, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 392 =======
# Loss => train:45.45906, valid:78.09016, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 393 =======
# Loss => train:45.58193, valid:78.05039, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 394 =======
# Loss => train:45.21809, valid:77.73775, Elapsed time => 0.434 sec
# =======================================
#
# ======== Epoch 395 =======
# Loss => train:44.95225, valid:78.99180, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 396 =======
# Loss => train:45.98268, valid:78.03506, Elapsed time => 0.437 sec
# =======================================
#
# ======== Epoch 397 =======
# Loss => train:45.37001, valid:77.54179, Elapsed time => 0.429 sec
# =======================================
#
# ======== Epoch 398 =======
# Loss => train:45.03878, valid:78.91980, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 399 =======
# Loss => train:45.06953, valid:79.41096, Elapsed time => 0.411 sec
# =======================================
#
# ======== Epoch 400 =======
# Loss => train:45.28409, valid:80.38596, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 401 =======
# Loss => train:45.19351, valid:77.84796, Elapsed time => 0.411 sec
# =======================================
#
# ======== Epoch 402 =======
# Loss => train:44.67438, valid:78.39658, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 403 =======
# Loss => train:44.66848, valid:77.79242, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 404 =======
# Loss => train:44.73635, valid:77.44873, Elapsed time => 0.436 sec
# =======================================
#
# ======== Epoch 405 =======
# Loss => train:44.43302, valid:77.99145, Elapsed time => 0.414 sec
# =======================================
#
# ======== Epoch 406 =======
# Loss => train:44.30910, valid:77.79522, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 407 =======
# Loss => train:44.75342, valid:78.94952, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 408 =======
# Loss => train:44.35619, valid:77.49832, Elapsed time => 0.435 sec
# =======================================
#
# ======== Epoch 409 =======
# Loss => train:44.24862, valid:77.47931, Elapsed time => 0.415 sec
# =======================================
#
# ======== Epoch 410 =======
# Loss => train:45.02830, valid:78.66585, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 411 =======
# Loss => train:43.87966, valid:76.91222, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 412 =======
# Loss => train:43.95968, valid:77.68138, Elapsed time => 0.431 sec
# =======================================
#
# ======== Epoch 413 =======
# Loss => train:43.94842, valid:77.23217, Elapsed time => 0.419 sec
# =======================================
#
# ======== Epoch 414 =======
# Loss => train:43.87397, valid:77.76155, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 415 =======
# Loss => train:43.71128, valid:77.42434, Elapsed time => 0.426 sec
# =======================================
#
# ======== Epoch 416 =======
# Loss => train:43.69025, valid:77.73535, Elapsed time => 0.424 sec
# =======================================
#
# ======== Epoch 417 =======
# Loss => train:43.81630, valid:77.90914, Elapsed time => 0.417 sec
# =======================================
#
# ======== Epoch 418 =======
# Loss => train:43.52778, valid:77.32983, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 419 =======
# Loss => train:43.68845, valid:77.37776, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 420 =======
# Loss => train:43.44339, valid:77.62482, Elapsed time => 0.423 sec
# =======================================
#
# ======== Epoch 421 =======
# Loss => train:43.45631, valid:77.71840, Elapsed time => 0.432 sec
# =======================================
#
# ======== Epoch 422 =======
# Loss => train:43.45887, valid:78.30035, Elapsed time => 0.439 sec
# =======================================
#
# ======== Epoch 423 =======
# Loss => train:43.48319, valid:80.23054, Elapsed time => 0.433 sec
# =======================================
#
# ======== Epoch 424 =======
# Loss => train:43.29845, valid:77.61945, Elapsed time => 0.427 sec
# =======================================
#
# ======== Epoch 425 =======
# Loss => train:43.04396, valid:77.26999, Elapsed time => 0.438 sec
# =======================================
#
# ======== Epoch 426 =======
# Loss => train:42.82310, valid:77.45444, Elapsed time => 0.449 sec
# =======================================

# %% [markdown]
# # Learning Curve

# %%
import matplotlib.pyplot as plt 

plt.plot(train_loss_history)
plt.plot(valid_loss_history)
plt.axhline(y=min(valid_loss_history), color='black', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# # Load best model

# %%
checkpoint = torch.load('./saved_model.pt')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
epoch = checkpoint['epoch']
loss = checkpoint['loss']

print(epoch, loss.item())
# Out:
# 411 76.91221618652344

# %% [markdown]
# # Evaluation

# %%
prediction = model(X_test)
loss = criterion(prediction[:,:,0], y_test)

print(f"loss: {loss:.5f}")
# Out:
# loss: 42.82201

# %%
for i in range(sequence_length):
    loss = criterion(prediction[:,i,0], y_test[:,i])
    print(f"loss of the {i+1}th sequence: {loss:.5f}")
# Out:
# loss of the 1th sequence: 46.14424
# loss of the 2th sequence: 43.66276
# loss of the 3th sequence: 38.57831
# loss of the 4th sequence: 42.90273

# %%
plt.figure(figsize=(15,6))
#plt.plot(y_test[:,2].detach().numpy())
plt.plot(df_test['pm2.5'].iloc[2:-(sequence_length-2)].values)
plt.plot(prediction[:,2,0].detach().numpy())
plt.show()
